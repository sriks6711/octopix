# %% [markdown]
# <a href="https://colab.research.google.com/github/sriks6711/octopix/blob/main/notebooks/how-to-generate-heatmaps-using-ultralytics-yolo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div align="center">
#
#   <a href="https://ultralytics.com/yolo" target="_blank">
#     <img width="1024", src="https://raw.githubusercontent.com/ultralytics/assets/main/yolov8/banner-yolov8.png"></a>
#
#   [中文](https://docs.ultralytics.com/zh/) | [한국어](https://docs.ultralytics.com/ko/) | [日本語](https://docs.ultralytics.com/ja/) | [Русский](https://docs.ultralytics.com/ru/) | [Deutsch](https://docs.ultralytics.com/de/) | [Français](https://docs.ultralytics.com/fr/) | [Español](https://docs.ultralytics.com/es/) | [Português](https://docs.ultralytics.com/pt/) | [Türkçe](https://docs.ultralytics.com/tr/) | [Tiếng Việt](https://docs.ultralytics.com/vi/) | [العربية](https://docs.ultralytics.com/ar/)
#
#   <a href="https://github.com/ultralytics/ultralytics/actions/workflows/ci.yml"><img src="https://github.com/ultralytics/ultralytics/actions/workflows/ci.yml/badge.svg" alt="Ultralytics CI"></a>
#   <a href="https://colab.research.google.com/github/ultralytics/notebooks/blob/main/notebooks/how-to-generate-heatmaps-using-ultralytics-yolo.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"></a>
#
#   <a href="https://ultralytics.com/discord"><img alt="Discord" src="https://img.shields.io/discord/1089800235347353640?logo=discord&logoColor=white&label=Discord&color=blue"></a>
#   <a href="https://community.ultralytics.com"><img alt="Ultralytics Forums" src="https://img.shields.io/discourse/users?server=https%3A%2F%2Fcommunity.ultralytics.com&logo=discourse&label=Forums&color=blue"></a>
#   <a href="https://reddit.com/r/ultralytics"><img alt="Ultralytics Reddit" src="https://img.shields.io/reddit/subreddit-subscribers/ultralytics?style=flat&logo=reddit&logoColor=white&label=Reddit&color=blue"></a>
#
#   Welcome to the Heatmaps generation using Ultralytics YOLO11 🚀 notebook! <a href="https://github.com/ultralytics/ultralytics">YOLO11</a> is the latest version of the YOLO (You Only Look Once) AI models developed by <a href="https://ultralytics.com">Ultralytics</a>. We hope that the resources in this notebook will help you get the most out of YOLO11. Please browse the YOLO11 <a href="https://docs.ultralytics.com/">Docs</a> for details, raise an issue on <a href="https://github.com/ultralytics/ultralytics">GitHub</a> for support, and join our <a href="https://ultralytics.com/discord">Discord</a> community for questions and discussions!</div>

# %% [markdown]
# # Generate Heatmaps using Ultralytics YOLO11
#
# This notebook serves as a starting point for generating the [heatmaps](https://docs.ultralytics.com/guides/heatmaps/) in videos or live streams using the YOLO11 model.
#
# ### What is Heatmap?
#
# - A heatmap generated with [Ultralytics YOLO11](https://github.com/ultralytics/ultralytics/) transforms complex data into a vibrant, color-coded matrix. This visual tool employs a spectrum of colors to represent varying data values, where warmer hues indicate higher intensities and cooler tones signify lower values. Heatmaps excel in visualizing intricate data patterns, correlations, and anomalies, offering an accessible and engaging approach to data interpretation across diverse domains.
#
# ### Why Choose Heatmaps for Data Analysis?
#
# - **Intuitive Data Distribution Visualization:** Heatmaps simplify the comprehension of data concentration and distribution, converting complex datasets into easy-to-understand visual formats.
# - **Efficient Pattern Detection:** By visualizing data in heatmap format, it becomes easier to spot trends, clusters, and outliers, facilitating quicker analysis and insights.
# - **Enhanced Spatial Analysis and Decision-Making:** Heatmaps are instrumental in illustrating spatial relationships, aiding in decision-making processes in sectors such as business intelligence, environmental studies, and urban planning.

# %% [markdown]
# ### Setup
#
# Pip install `ultralytics` and [dependencies](https://github.com/ultralytics/ultralytics/blob/main/pyproject.toml) and check software and hardware.
#
# [![PyPI - Version](https://img.shields.io/pypi/v/ultralytics?logo=pypi&logoColor=white)](https://pypi.org/project/ultralytics/) [![Downloads](https://static.pepy.tech/badge/ultralytics)](https://www.pepy.tech/projects/ultralytics) [![PyPI - Python Version](https://img.shields.io/pypi/pyversions/ultralytics?logo=python&logoColor=gold)](https://pypi.org/project/ultralytics/)

# %%
# %pip install ultralytics

import cv2
import ultralytics
from ultralytics import solutions

ultralytics.checks()
# Out:
# Ultralytics 8.3.95 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 41.2/112.6 GB disk)

# %% [markdown]
# ### Read the Video File
#
# You can either read the video file directly or stream the content from an RTSP (Real-Time Streaming Protocol) source, allowing for flexible video input depending on your needs. We will also set up the video writer to handle the output video writing.

# %%
cap = cv2.VideoCapture("fall-istockphoto.mp4")
assert cap.isOpened(), "Error reading video file"
w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH, cv2.CAP_PROP_FRAME_HEIGHT, cv2.CAP_PROP_FPS))

# Video writer
video_writer = cv2.VideoWriter("heatmap.avi", cv2.VideoWriter_fourcc(*"mp4v"), fps, (w, h))

# %% [markdown]
# ### Define Region Coordinates (Optional)
#
# `Heatmap` solution doesn't require region coordinates by default, but If you want to count the objects in parallel during generation of heatmaps, you can pass the region coordinates for line counting.

# %%
# Define region points
# region_points = [(20, 400), (1080, 400)]  # For line counting
# region_points = [(20, 400), (1080, 400), (1080, 360), (20, 360)]  # For rectangle region counting
# region_points = [(20, 400), (1080, 400), (1080, 360), (20, 360), (20, 400)]  # For polygon region counting

# %% [markdown]
# ### Initialize the Heatmap Class
#
# Next, we will initialize the Heatmap class to track objects in each video frame and highlight the areas with the highest concentration of activity.

# %%
# Init heatmap
heatmap = solutions.Heatmap(
    show=True,  # Display the output
    model="yolo11n.pt",  # Path to the YOLO11 model file
    colormap=cv2.COLORMAP_PARULA,  # Colormap of heatmap
    # region=region_points,  # If you want to do object counting with heatmaps, you can pass region_points
    # classes=[0, 2],  # If you want to generate heatmap for specific classes i.e person and car.
    # show_in=True,  # Display in counts
    # show_out=True,  # Display out counts
    # line_width=2,  # Adjust the line width for bounding boxes and text display
)
# Out:
# Ultralytics Solutions: ✅ {'region': None, 'show_in': True, 'show_out': True, 'colormap': 12, 'up_angle': 145.0, 'down_angle': 90, 'kpts': [6, 8, 10], 'analytics_type': 'line', 'json_file': None, 'records': 5, 'show': True, 'model': 'yolo11n.pt'}
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt'...
# 100%|██████████| 5.35M/5.35M [00:00<00:00, 86.6MB/s]
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()

# %% [markdown]
# ### Process Video Frames
#
# In this step, we will analyze each video frame for object detection and tracking. We also generate heatmaps to highlight areas with the highest object concentration.

# %%
# Process video
while cap.isOpened():
    success, im0 = cap.read()
    if not success:
        print("Video frame is empty or video processing has been successfully completed.")
        break
    results = heatmap(im0)  # generate heatmap the objects
    video_writer.write(results.plot_im)  # write the video frame

cap.release()
video_writer.release()  # release the video_writer
cv2.destroyAllWindows()
# Out:
# requirements: Ultralytics requirement ['lap>=0.5.12'] not found, attempting AutoUpdate...
# Collecting lap>=0.5.12
#   Downloading lap-0.5.12-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.2 kB)
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.11/dist-packages (from lap>=0.5.12) (2.0.2)
# Downloading lap-0.5.12-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 43.0 MB/s eta 0:00:00
# Installing collected packages: lap
# Successfully installed lap-0.5.12
#
# requirements: AutoUpdate success ✅ 2.8s, installed 1 package: ['lap>=0.5.12']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
#
# 0: 384x640 2 persons, 56.3ms
# Speed: 16.8ms preprocess, 56.3ms inference, 349.7ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 2 persons, 9.9ms
# Speed: 3.3ms preprocess, 9.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 2 persons, 11.8ms
# Speed: 3.5ms preprocess, 11.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 2 persons, 18.5ms
# Speed: 3.7ms preprocess, 18.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 2 persons, 11.6ms
# Speed: 2.1ms preprocess, 11.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 2 persons, 12.2ms
# Speed: 2.9ms preprocess, 12.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 2 persons, 12.8ms
# Speed: 3.4ms preprocess, 12.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 2 persons, 11.3ms
# Speed: 3.6ms preprocess, 11.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 2 persons, 11.3ms
# Speed: 2.8ms preprocess, 11.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 2 persons, 11.0ms
# Speed: 2.6ms preprocess, 11.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 2 persons, 13.3ms
# Speed: 3.4ms preprocess, 13.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 2 persons, 10.9ms
# Speed: 3.3ms preprocess, 10.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 3 persons, 10.3ms
# Speed: 3.0ms preprocess, 10.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 10.0ms
# Speed: 1.9ms preprocess, 10.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 10.2ms
# Speed: 2.7ms preprocess, 10.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 10.2ms
# Speed: 3.3ms preprocess, 10.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 2 persons, 10.6ms
# Speed: 2.9ms preprocess, 10.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 2 persons, 10.6ms
# Speed: 3.3ms preprocess, 10.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 2 persons, 21.0ms
# Speed: 3.2ms preprocess, 21.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 2 persons, 14.4ms
# Speed: 3.1ms preprocess, 14.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 2 persons, 14.2ms
# Speed: 3.4ms preprocess, 14.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 3 persons, 14.8ms
# Speed: 3.1ms preprocess, 14.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 10.2ms
# Speed: 2.7ms preprocess, 10.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 9.3ms
# Speed: 3.0ms preprocess, 9.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 2 persons, 9.6ms
# Speed: 3.0ms preprocess, 9.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 3 persons, 9.8ms
# Speed: 2.0ms preprocess, 9.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 4 persons, 10.1ms
# Speed: 2.7ms preprocess, 10.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=4)
#
# 0: 384x640 4 persons, 1 umbrella, 10.4ms
# Speed: 3.3ms preprocess, 10.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=5)
#
# 0: 384x640 3 persons, 1 umbrella, 9.5ms
# Speed: 3.0ms preprocess, 9.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=4)
#
# 0: 384x640 3 persons, 1 umbrella, 10.2ms
# Speed: 3.0ms preprocess, 10.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=4)
#
# 0: 384x640 2 persons, 1 dog, 1 handbag, 10.9ms
# Speed: 3.1ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=4)
#
# 0: 384x640 3 persons, 1 dog, 9.7ms
# Speed: 3.3ms preprocess, 9.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=4)
#
# 0: 384x640 3 persons, 1 dog, 9.8ms
# Speed: 1.8ms preprocess, 9.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=4)
#
# 0: 384x640 2 persons, 9.8ms
# Speed: 2.2ms preprocess, 9.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 2 persons, 10.0ms
# Speed: 3.1ms preprocess, 10.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 2 persons, 9.5ms
# Speed: 3.0ms preprocess, 9.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 1 person, 11.7ms
# Speed: 2.0ms preprocess, 11.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 384x640 1 person, 12.1ms
# Speed: 2.6ms preprocess, 12.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 384x640 1 person, 13.9ms
# Speed: 2.9ms preprocess, 13.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 384x640 1 person, 13.5ms
# Speed: 2.1ms preprocess, 13.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 384x640 2 persons, 9.8ms
# Speed: 2.5ms preprocess, 9.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 2 persons, 10.5ms
# Speed: 4.0ms preprocess, 10.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 3 persons, 10.4ms
# Speed: 3.1ms preprocess, 10.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 8.9ms
# Speed: 2.7ms preprocess, 8.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 10.5ms
# Speed: 3.2ms preprocess, 10.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 10.0ms
# Speed: 2.8ms preprocess, 10.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 10.2ms
# Speed: 2.8ms preprocess, 10.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 10.4ms
# Speed: 3.0ms preprocess, 10.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 2 persons, 1 umbrella, 1 bowl, 10.2ms
# Speed: 2.7ms preprocess, 10.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=4)
#
# 0: 384x640 2 persons, 1 bed, 12.2ms
# Speed: 3.4ms preprocess, 12.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 2 persons, 1 umbrella, 10.4ms
# Speed: 3.3ms preprocess, 10.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 2 persons, 1 umbrella, 10.8ms
# Speed: 2.3ms preprocess, 10.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 2 persons, 1 umbrella, 10.2ms
# Speed: 2.2ms preprocess, 10.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 2 persons, 10.5ms
# Speed: 3.3ms preprocess, 10.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 2 persons, 1 couch, 9.4ms
# Speed: 3.0ms preprocess, 9.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 2 persons, 1 couch, 10.0ms
# Speed: 2.1ms preprocess, 10.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 2 persons, 1 couch, 14.2ms
# Speed: 2.3ms preprocess, 14.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 2 persons, 1 bed, 14.0ms
# Speed: 2.7ms preprocess, 14.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 1 person, 1 couch, 12.7ms
# Speed: 2.4ms preprocess, 12.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 1 person, 1 bed, 12.6ms
# Speed: 3.6ms preprocess, 12.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 1 person, 1 bed, 11.1ms
# Speed: 3.9ms preprocess, 11.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 1 person, 1 bed, 11.6ms
# Speed: 4.8ms preprocess, 11.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 1 person, 1 couch, 11.2ms
# Speed: 3.4ms preprocess, 11.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 1 person, 1 couch, 10.8ms
# Speed: 2.9ms preprocess, 10.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 3 persons, 1 couch, 9.8ms
# Speed: 2.9ms preprocess, 9.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=4)
#
# 0: 384x640 3 persons, 1 couch, 15.6ms
# Speed: 2.6ms preprocess, 15.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=4)
#
# 0: 384x640 3 persons, 1 couch, 13.6ms
# Speed: 2.6ms preprocess, 13.6ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=4)
#
# 0: 384x640 3 persons, 20.8ms
# Speed: 4.1ms preprocess, 20.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 15.7ms
# Speed: 3.6ms preprocess, 15.7ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 11.8ms
# Speed: 2.7ms preprocess, 11.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 13.1ms
# Speed: 2.9ms preprocess, 13.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 13.7ms
# Speed: 2.9ms preprocess, 13.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 14.3ms
# Speed: 5.1ms preprocess, 14.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 23.2ms
# Speed: 5.0ms preprocess, 23.2ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 13.6ms
# Speed: 2.6ms preprocess, 13.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 2 persons, 1 bed, 1 teddy bear, 11.9ms
# Speed: 4.1ms preprocess, 11.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=4)
#
# 0: 384x640 3 persons, 1 teddy bear, 12.7ms
# Speed: 2.6ms preprocess, 12.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=4)
#
# 0: 384x640 3 persons, 1 teddy bear, 16.2ms
# Speed: 2.8ms preprocess, 16.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=4)
#
# 0: 384x640 2 persons, 1 bed, 1 teddy bear, 17.4ms
# Speed: 2.8ms preprocess, 17.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=4)
#
# 0: 384x640 2 persons, 1 bed, 11.8ms
# Speed: 4.4ms preprocess, 11.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 2 persons, 1 bed, 12.3ms
# Speed: 3.1ms preprocess, 12.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 2 persons, 1 bed, 17.4ms
# Speed: 3.1ms preprocess, 17.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 2 persons, 1 bed, 17.7ms
# Speed: 2.8ms preprocess, 17.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 11.9ms
# Speed: 4.9ms preprocess, 11.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 2 persons, 1 couch, 13.1ms
# Speed: 5.0ms preprocess, 13.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 2 persons, 1 bed, 16.7ms
# Speed: 4.8ms preprocess, 16.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 2 persons, 1 bed, 16.6ms
# Speed: 4.7ms preprocess, 16.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 2 persons, 1 bed, 16.4ms
# Speed: 2.7ms preprocess, 16.4ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 12.9ms
# Speed: 2.8ms preprocess, 12.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 17.1ms
# Speed: 2.8ms preprocess, 17.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 20.2ms
# Speed: 4.5ms preprocess, 20.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 2 persons, 1 couch, 19.6ms
# Speed: 3.0ms preprocess, 19.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 2 persons, 1 couch, 15.6ms
# Speed: 2.9ms preprocess, 15.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 2 persons, 1 couch, 17.6ms
# Speed: 3.1ms preprocess, 17.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 2 persons, 1 couch, 18.7ms
# Speed: 3.0ms preprocess, 18.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 2 persons, 1 couch, 17.1ms
# Speed: 3.1ms preprocess, 17.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 2 persons, 1 couch, 18.9ms
# Speed: 3.4ms preprocess, 18.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 2 persons, 1 bed, 12.3ms
# Speed: 3.5ms preprocess, 12.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 9.9ms
# Speed: 2.7ms preprocess, 9.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 2 persons, 1 bed, 16.6ms
# Speed: 5.0ms preprocess, 16.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 12.8ms
# Speed: 3.0ms preprocess, 12.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 10.7ms
# Speed: 3.5ms preprocess, 10.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 1 person, 1 bed, 10.8ms
# Speed: 1.9ms preprocess, 10.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 2 persons, 9.7ms
# Speed: 2.8ms preprocess, 9.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 2 persons, 9.8ms
# Speed: 3.0ms preprocess, 9.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 3 persons, 10.4ms
# Speed: 2.8ms preprocess, 10.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 10.4ms
# Speed: 3.1ms preprocess, 10.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 14.9ms
# Speed: 2.9ms preprocess, 14.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 10.2ms
# Speed: 3.2ms preprocess, 10.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 9.9ms
# Speed: 2.5ms preprocess, 9.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 10.5ms
# Speed: 2.9ms preprocess, 10.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 11.8ms
# Speed: 2.8ms preprocess, 11.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 9.4ms
# Speed: 2.6ms preprocess, 9.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 10.2ms
# Speed: 4.5ms preprocess, 10.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 10.1ms
# Speed: 2.0ms preprocess, 10.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 1 refrigerator, 10.9ms
# Speed: 3.6ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=4)
#
# 0: 384x640 3 persons, 1 refrigerator, 10.7ms
# Speed: 3.5ms preprocess, 10.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=4)
#
# 0: 384x640 3 persons, 13.0ms
# Speed: 2.8ms preprocess, 13.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 14.3ms
# Speed: 3.1ms preprocess, 14.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 14.0ms
# Speed: 2.8ms preprocess, 14.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 10.0ms
# Speed: 2.8ms preprocess, 10.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 10.3ms
# Speed: 2.4ms preprocess, 10.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 9.8ms
# Speed: 2.5ms preprocess, 9.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 10.7ms
# Speed: 3.0ms preprocess, 10.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 10.0ms
# Speed: 3.3ms preprocess, 10.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 4 persons, 12.7ms
# Speed: 3.5ms preprocess, 12.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=4)
#
# 0: 384x640 4 persons, 11.8ms
# Speed: 3.3ms preprocess, 11.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=4)
#
# 0: 384x640 4 persons, 13.1ms
# Speed: 3.0ms preprocess, 13.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=4)
#
# 0: 384x640 4 persons, 10.8ms
# Speed: 2.5ms preprocess, 10.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=4)
#
# 0: 384x640 3 persons, 1 backpack, 16.0ms
# Speed: 2.9ms preprocess, 16.0ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=4)
#
# 0: 384x640 3 persons, 1 backpack, 10.0ms
# Speed: 2.7ms preprocess, 10.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=4)
#
# 0: 384x640 3 persons, 1 backpack, 9.8ms
# Speed: 3.1ms preprocess, 9.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=4)
#
# 0: 384x640 3 persons, 1 backpack, 9.0ms
# Speed: 2.4ms preprocess, 9.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=4)
#
# 0: 384x640 3 persons, 1 backpack, 10.0ms
# Speed: 2.6ms preprocess, 10.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=4)
#
# 0: 384x640 2 persons, 1 backpack, 10.1ms
# Speed: 2.8ms preprocess, 10.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 2 persons, 1 backpack, 10.6ms
# Speed: 3.2ms preprocess, 10.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 2 persons, 1 backpack, 13.7ms
# Speed: 2.5ms preprocess, 13.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 2 persons, 1 suitcase, 14.6ms
# Speed: 3.3ms preprocess, 14.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 2 persons, 1 backpack, 13.0ms
# Speed: 3.7ms preprocess, 13.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 2 persons, 1 suitcase, 10.2ms
# Speed: 3.1ms preprocess, 10.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 2 persons, 1 suitcase, 10.7ms
# Speed: 3.7ms preprocess, 10.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 2 persons, 1 suitcase, 12.0ms
# Speed: 3.1ms preprocess, 12.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 2 persons, 9.8ms
# Speed: 3.1ms preprocess, 9.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 2 persons, 9.6ms
# Speed: 2.6ms preprocess, 9.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 2 persons, 12.9ms
# Speed: 2.8ms preprocess, 12.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 2 persons, 10.0ms
# Speed: 2.8ms preprocess, 10.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 2 persons, 11.9ms
# Speed: 2.5ms preprocess, 11.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 2 persons, 9.0ms
# Speed: 2.5ms preprocess, 9.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 2 persons, 11.3ms
# Speed: 2.5ms preprocess, 11.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 2 persons, 11.6ms
# Speed: 2.8ms preprocess, 11.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 2 persons, 9.4ms
# Speed: 2.9ms preprocess, 9.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 2 persons, 9.8ms
# Speed: 3.3ms preprocess, 9.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 2 persons, 9.2ms
# Speed: 2.6ms preprocess, 9.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 2 persons, 9.4ms
# Speed: 2.4ms preprocess, 9.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 2 persons, 12.0ms
# Speed: 3.9ms preprocess, 12.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 2 persons, 16.3ms
# Speed: 5.6ms preprocess, 16.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 2 persons, 13.5ms
# Speed: 3.6ms preprocess, 13.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 2 persons, 13.7ms
# Speed: 2.9ms preprocess, 13.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 2 persons, 9.1ms
# Speed: 2.5ms preprocess, 9.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 2 persons, 9.3ms
# Speed: 2.6ms preprocess, 9.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 3 persons, 11.5ms
# Speed: 3.1ms preprocess, 11.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 10.9ms
# Speed: 3.1ms preprocess, 10.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 10.4ms
# Speed: 2.7ms preprocess, 10.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 9.8ms
# Speed: 2.9ms preprocess, 9.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 11.2ms
# Speed: 3.0ms preprocess, 11.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 16.2ms
# Speed: 4.4ms preprocess, 16.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 11.0ms
# Speed: 2.6ms preprocess, 11.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 10.1ms
# Speed: 2.8ms preprocess, 10.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 10.6ms
# Speed: 2.9ms preprocess, 10.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 10.6ms
# Speed: 2.8ms preprocess, 10.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 10.0ms
# Speed: 2.8ms preprocess, 10.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 2 persons, 1 potted plant, 9.7ms
# Speed: 2.8ms preprocess, 9.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 2 persons, 1 potted plant, 12.0ms
# Speed: 3.2ms preprocess, 12.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 2 persons, 1 potted plant, 9.9ms
# Speed: 3.2ms preprocess, 9.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 2 persons, 1 potted plant, 10.3ms
# Speed: 3.3ms preprocess, 10.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 14.0ms
# Speed: 1.9ms preprocess, 14.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 15.1ms
# Speed: 3.8ms preprocess, 15.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 13.2ms
# Speed: 2.6ms preprocess, 13.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 1 backpack, 13.3ms
# Speed: 2.9ms preprocess, 13.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=4)
#
# 0: 384x640 3 persons, 1 backpack, 9.4ms
# Speed: 2.8ms preprocess, 9.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=4)
#
# 0: 384x640 3 persons, 1 backpack, 12.5ms
# Speed: 2.9ms preprocess, 12.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=4)
#
# 0: 384x640 3 persons, 1 backpack, 11.0ms
# Speed: 2.7ms preprocess, 11.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=4)
#
# 0: 384x640 3 persons, 1 backpack, 10.0ms
# Speed: 3.0ms preprocess, 10.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=4)
#
# 0: 384x640 3 persons, 1 backpack, 9.7ms
# Speed: 2.6ms preprocess, 9.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=4)
#
# 0: 384x640 3 persons, 1 backpack, 10.4ms
# Speed: 2.7ms preprocess, 10.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=4)
#
# 0: 384x640 3 persons, 1 backpack, 9.8ms
# Speed: 2.6ms preprocess, 9.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=4)
#
# 0: 384x640 3 persons, 2 backpacks, 18.6ms
# Speed: 3.0ms preprocess, 18.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=5)
#
# 0: 384x640 3 persons, 1 backpack, 10.6ms
# Speed: 2.8ms preprocess, 10.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=4)
#
# 0: 384x640 3 persons, 1 backpack, 9.2ms
# Speed: 2.2ms preprocess, 9.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=4)
#
# 0: 384x640 2 persons, 1 backpack, 1 potted plant, 9.7ms
# Speed: 3.3ms preprocess, 9.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=4)
#
# 0: 384x640 2 persons, 1 backpack, 1 potted plant, 10.0ms
# Speed: 3.1ms preprocess, 10.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=4)
#
# 0: 384x640 2 persons, 1 backpack, 10.3ms
# Speed: 2.8ms preprocess, 10.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 2 persons, 1 backpack, 10.8ms
# Speed: 3.0ms preprocess, 10.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 2 persons, 1 backpack, 9.0ms
# Speed: 2.8ms preprocess, 9.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 2 persons, 1 backpack, 10.0ms
# Speed: 2.7ms preprocess, 10.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 2 persons, 1 backpack, 9.9ms
# Speed: 2.7ms preprocess, 9.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 2 persons, 14.9ms
# Speed: 2.7ms preprocess, 14.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 2 persons, 13.5ms
# Speed: 3.4ms preprocess, 13.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 2 persons, 12.3ms
# Speed: 2.6ms preprocess, 12.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 2 persons, 9.7ms
# Speed: 2.6ms preprocess, 9.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 2 persons, 11.3ms
# Speed: 2.9ms preprocess, 11.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 2 persons, 9.6ms
# Speed: 2.8ms preprocess, 9.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 2 persons, 10.0ms
# Speed: 3.0ms preprocess, 10.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 2 persons, 11.0ms
# Speed: 2.7ms preprocess, 11.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 3 persons, 11.8ms
# Speed: 2.8ms preprocess, 11.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 10.5ms
# Speed: 3.2ms preprocess, 10.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 2 persons, 9.3ms
# Speed: 1.9ms preprocess, 9.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 2 persons, 17.5ms
# Speed: 2.8ms preprocess, 17.5ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 2 persons, 11.6ms
# Speed: 3.2ms preprocess, 11.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 2 persons, 15.8ms
# Speed: 3.5ms preprocess, 15.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 2 persons, 10.4ms
# Speed: 3.1ms preprocess, 10.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 3 persons, 11.5ms
# Speed: 3.0ms preprocess, 11.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 10.6ms
# Speed: 2.7ms preprocess, 10.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 10.0ms
# Speed: 3.4ms preprocess, 10.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 2 persons, 10.5ms
# Speed: 3.2ms preprocess, 10.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 2 persons, 13.2ms
# Speed: 2.7ms preprocess, 13.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 3 persons, 16.2ms
# Speed: 3.0ms preprocess, 16.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 2 persons, 14.2ms
# Speed: 2.9ms preprocess, 14.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 2 persons, 15.2ms
# Speed: 2.8ms preprocess, 15.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 3 persons, 10.1ms
# Speed: 2.9ms preprocess, 10.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 11.8ms
# Speed: 2.8ms preprocess, 11.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 4 persons, 9.3ms
# Speed: 2.7ms preprocess, 9.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=4)
#
# 0: 384x640 3 persons, 9.6ms
# Speed: 3.1ms preprocess, 9.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 10.2ms
# Speed: 2.8ms preprocess, 10.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 10.4ms
# Speed: 2.2ms preprocess, 10.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 10.5ms
# Speed: 3.1ms preprocess, 10.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 10.2ms
# Speed: 3.2ms preprocess, 10.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 9.9ms
# Speed: 3.1ms preprocess, 9.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 2 persons, 11.2ms
# Speed: 2.9ms preprocess, 11.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 2 persons, 9.9ms
# Speed: 2.9ms preprocess, 9.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 2 persons, 11.0ms
# Speed: 2.9ms preprocess, 11.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 2 persons, 10.7ms
# Speed: 2.9ms preprocess, 10.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 2 persons, 1 backpack, 10.4ms
# Speed: 2.9ms preprocess, 10.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 2 persons, 1 backpack, 13.6ms
# Speed: 2.9ms preprocess, 13.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 10.7ms
# Speed: 3.1ms preprocess, 10.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 15.1ms
# Speed: 3.1ms preprocess, 15.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 2 persons, 1 backpack, 18.8ms
# Speed: 3.3ms preprocess, 18.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 2 persons, 1 backpack, 14.7ms
# Speed: 2.7ms preprocess, 14.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 2 persons, 1 backpack, 12.9ms
# Speed: 3.2ms preprocess, 12.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 2 persons, 1 backpack, 9.1ms
# Speed: 2.8ms preprocess, 9.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 2 persons, 9.5ms
# Speed: 4.6ms preprocess, 9.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 2 persons, 11.1ms
# Speed: 3.4ms preprocess, 11.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 2 persons, 10.4ms
# Speed: 3.0ms preprocess, 10.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 3 persons, 12.6ms
# Speed: 4.0ms preprocess, 12.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 10.7ms
# Speed: 2.9ms preprocess, 10.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 9.5ms
# Speed: 2.6ms preprocess, 9.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 10.6ms
# Speed: 3.0ms preprocess, 10.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 19.0ms
# Speed: 2.8ms preprocess, 19.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 10.2ms
# Speed: 2.6ms preprocess, 10.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 9.0ms
# Speed: 2.5ms preprocess, 9.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 9.1ms
# Speed: 2.6ms preprocess, 9.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 9.3ms
# Speed: 2.8ms preprocess, 9.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 9.1ms
# Speed: 3.6ms preprocess, 9.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 17.9ms
# Speed: 3.0ms preprocess, 17.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 2 persons, 12.8ms
# Speed: 3.0ms preprocess, 12.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 2 persons, 14.4ms
# Speed: 2.5ms preprocess, 14.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 2 persons, 12.5ms
# Speed: 4.0ms preprocess, 12.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 2 persons, 13.6ms
# Speed: 2.8ms preprocess, 13.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 2 persons, 12.7ms
# Speed: 2.5ms preprocess, 12.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 2 persons, 9.6ms
# Speed: 2.5ms preprocess, 9.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 2 persons, 10.5ms
# Speed: 2.9ms preprocess, 10.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 2 persons, 9.7ms
# Speed: 3.2ms preprocess, 9.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 2 persons, 9.2ms
# Speed: 2.8ms preprocess, 9.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 2 persons, 9.8ms
# Speed: 2.6ms preprocess, 9.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 3 persons, 12.7ms
# Speed: 2.8ms preprocess, 12.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 10.4ms
# Speed: 3.3ms preprocess, 10.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 10.9ms
# Speed: 3.2ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 14.3ms
# Speed: 3.5ms preprocess, 14.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 14.2ms
# Speed: 3.8ms preprocess, 14.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 9.3ms
# Speed: 2.7ms preprocess, 9.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 9.8ms
# Speed: 2.9ms preprocess, 9.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 4 persons, 1 handbag, 12.4ms
# Speed: 2.7ms preprocess, 12.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=5)
#
# 0: 384x640 4 persons, 1 handbag, 10.2ms
# Speed: 3.0ms preprocess, 10.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=5)
#
# 0: 384x640 4 persons, 1 handbag, 9.6ms
# Speed: 2.9ms preprocess, 9.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=5)
#
# 0: 384x640 3 persons, 1 handbag, 10.0ms
# Speed: 2.8ms preprocess, 10.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=4)
#
# 0: 384x640 3 persons, 1 handbag, 17.9ms
# Speed: 3.5ms preprocess, 17.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=4)
#
# 0: 384x640 3 persons, 1 handbag, 13.9ms
# Speed: 2.5ms preprocess, 13.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=4)
#
# 0: 384x640 3 persons, 1 handbag, 13.0ms
# Speed: 3.4ms preprocess, 13.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=4)
#
# 0: 384x640 3 persons, 10.5ms
# Speed: 3.7ms preprocess, 10.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 4 persons, 9.8ms
# Speed: 3.0ms preprocess, 9.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=4)
#
# 0: 384x640 4 persons, 12.5ms
# Speed: 3.0ms preprocess, 12.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=4)
#
# 0: 384x640 4 persons, 9.8ms
# Speed: 2.8ms preprocess, 9.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=4)
#
# 0: 384x640 4 persons, 9.8ms
# Speed: 2.7ms preprocess, 9.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=4)
#
# 0: 384x640 4 persons, 9.5ms
# Speed: 2.8ms preprocess, 9.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=4)
#
# 0: 384x640 4 persons, 10.2ms
# Speed: 2.1ms preprocess, 10.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=4)
#
# 0: 384x640 4 persons, 10.4ms
# Speed: 3.3ms preprocess, 10.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=4)
#
# 0: 384x640 4 persons, 9.9ms
# Speed: 3.1ms preprocess, 9.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=4)
#
# 0: 384x640 4 persons, 9.4ms
# Speed: 2.5ms preprocess, 9.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=4)
#
# 0: 384x640 4 persons, 18.7ms
# Speed: 2.9ms preprocess, 18.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=4)
#
# 0: 384x640 4 persons, 9.7ms
# Speed: 2.7ms preprocess, 9.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=4)
#
# 0: 384x640 4 persons, 9.9ms
# Speed: 2.9ms preprocess, 9.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=4)
#
# 0: 384x640 4 persons, 9.5ms
# Speed: 2.7ms preprocess, 9.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=4)
#
# 0: 384x640 4 persons, 16.5ms
# Speed: 2.5ms preprocess, 16.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=4)
#
# 0: 384x640 4 persons, 18.6ms
# Speed: 2.6ms preprocess, 18.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=4)
#
# 0: 384x640 4 persons, 18.6ms
# Speed: 2.7ms preprocess, 18.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=4)
#
# 0: 384x640 4 persons, 21.5ms
# Speed: 2.6ms preprocess, 21.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=4)
#
# 0: 384x640 4 persons, 12.2ms
# Speed: 5.1ms preprocess, 12.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=4)
#
# 0: 384x640 3 persons, 12.8ms
# Speed: 5.0ms preprocess, 12.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 15.0ms
# Speed: 4.2ms preprocess, 15.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 25.3ms
# Speed: 3.1ms preprocess, 25.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 12.6ms
# Speed: 2.7ms preprocess, 12.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 13.1ms
# Speed: 2.6ms preprocess, 13.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 12.7ms
# Speed: 2.6ms preprocess, 12.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 25.2ms
# Speed: 2.8ms preprocess, 25.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 13.3ms
# Speed: 2.6ms preprocess, 13.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 13.5ms
# Speed: 2.6ms preprocess, 13.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 2 persons, 12.8ms
# Speed: 2.6ms preprocess, 12.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 2 persons, 23.4ms
# Speed: 5.2ms preprocess, 23.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 2 persons, 16.8ms
# Speed: 3.7ms preprocess, 16.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 2 persons, 14.0ms
# Speed: 3.0ms preprocess, 14.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 3 persons, 11.9ms
# Speed: 2.8ms preprocess, 11.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 2 persons, 13.6ms
# Speed: 3.8ms preprocess, 13.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 2 persons, 11.7ms
# Speed: 2.8ms preprocess, 11.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 2 persons, 12.3ms
# Speed: 3.4ms preprocess, 12.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 2 persons, 14.1ms
# Speed: 3.3ms preprocess, 14.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 2 persons, 13.0ms
# Speed: 3.2ms preprocess, 13.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 2 persons, 12.9ms
# Speed: 3.4ms preprocess, 12.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 2 persons, 15.6ms
# Speed: 3.0ms preprocess, 15.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 2 persons, 23.5ms
# Speed: 3.0ms preprocess, 23.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 2 persons, 19.4ms
# Speed: 2.7ms preprocess, 19.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 1 person, 12.6ms
# Speed: 3.1ms preprocess, 12.6ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=1)
#
# 0: 384x640 2 persons, 16.0ms
# Speed: 3.7ms preprocess, 16.0ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 2 persons, 22.6ms
# Speed: 2.7ms preprocess, 22.6ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 2 persons, 24.0ms
# Speed: 2.8ms preprocess, 24.0ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 2 persons, 12.7ms
# Speed: 2.7ms preprocess, 12.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 2 persons, 20.0ms
# Speed: 2.7ms preprocess, 20.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=2)
#
# 0: 384x640 2 persons, 1 handbag, 16.5ms
# Speed: 2.7ms preprocess, 16.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=3)
#
# 0: 384x640 3 persons, 1 handbag, 16.3ms
# Speed: 5.9ms preprocess, 16.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=4)
#
# 0: 384x640 3 persons, 1 handbag, 19.6ms
# Speed: 3.4ms preprocess, 19.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 🚀 Results: SolutionResults(total_tracks=4)
# Video frame is empty or video processing has been successfully completed.
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-6-2a583fcad6d0> in <cell line: 0>()
#      10 cap.release()
#      11 video_writer.release()  # release the video_writer
# ---> 12 cv2.destroyAllWindows()
#
# error: OpenCV(4.11.0) /io/opencv/modules/highgui/src/window.cpp:1295: error: (-2:Unspecified error) The function is not implemented. Rebuild the library with Windows, GTK+ 2.x or Cocoa support. If you are on Ubuntu or Debian, install libgtk2.0-dev and pkg-config, then re-run cmake or configure script in function 'cvDestroyAllWindows'

# %% [markdown]
# ![Ultralytics YOLO11 Retail Heatmap](https://github.com/ultralytics/docs/releases/download/0/ultralytics-yolov8-retail-heatmap.avif)

# %% [markdown]
# Crafted with 💙 by [Ultralytics](https://ultralytics.com/)
#
# 🌟 Explore and star the [Ultralytics Notebooks](https://github.com/ultralytics/notebooks/) to supercharge your AI journey! 🚀
